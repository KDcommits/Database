# %% [markdown]
# <h2 align="center"> SQL </h2>

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# **SQL Order of Execution:**<br>
# **SELECT > FROM > WHERE > GROUP BY > HAVING > ORDER BY >LIMIT**

# %% [markdown]
# #### Useful Links :<br>
# 1. Aggregate Function : https://www.mysqltutorial.org/mysql-aggregate-functions.aspx
# 2. Having Clause : https://stackoverflow.com/questions/15767794/sql-how-to-filter-after-aggregation
# 3. Regexp : https://www.geeksforgeeks.org/mysql-regular-expressions-regexp/
# 4. Intersect : https://www.mysqltutorial.org/mysql-intersect/
# 5. Minus : https://www.mysqltutorial.org/mysql-minus/
# 6. Indexing : https://dev.mysql.com/doc/refman/8.0/en/mysql-indexes.html
# 7. Schemas : https://www.folkstalk.com/2010/01/data-warehouse-dimensional-modelling.html
# 8. OLTP vs. OLAP : https://www.datawarehouse4u.info/OLTP-vs-OLAP.html
# 9. Composite Primary Key : https://dba.stackexchange.com/questions/57548/how-to-set-up-multiple-fields-as-primary-key-in-mysql

# %% [markdown]
# **Primary keys vs Foreign keys:**<br>
# <u>The foreign key in one table is meant to reference the primary key of another table.</u>
#
#     - Primary keys are unique They cannot repeat, so there is only one instance of each primary key value in a column
#     - Foreign keys are non-unique They can repeat, so there may be many instances of each foreign key value in a column
#
# Example :![image.png](attachment:image.png)

# %% [markdown]
# #### Constraints in RDBMS
#
# 1. **Entity Constraint:**
#     - Unique : This constraint is used for columns that need unique values. For example, 'employee ids' should be unique in an 'employees' table.
#     - Null : This constraint is used to determine the columns that can have null values. For example, an employee may not need to specify his/her location, which means the 'location' column can have null values in an 'employees' table.
#     - Primary Key: This constraint is used to determine the column that uniquely identifies a table. For example, 'employee ids' uniquely identify every employee. Two employees may have the same name or the same salary, but not the same employee id.<br>
#
# 2. **Referential Constraints:**<br>
# These are used to restrict the values taken by a column in one table based on the values that exist in another table.
#     -  Foreign key: Foreign key in a table is valid only if it also appears as a primary key in the table to which it refers.
#
#
# 3. **Semantic Constraints:**<br>
# semantic constraints impose additional restrictions on the values in a column.Allowing only certain values in a column and ensuring that the values are in a specified format or belong to a certain range. For example, all mobile numbers in India start with '+91', followed by 10 digits. Using a semantic constraint for this requirement ensures that we do not get incorrect data for any row: For example, a row with a phone number +91987654321 would not be allowed to enter the database as it has only 9 digits after the country code.

# %% [markdown]
# ##### Comments
#
# 1. -- Standard SQL comment
# 2. \# Non-Standard SQL Comment
# 3. /* Multiline
#       Comment */

# %% [markdown]
# ###### DATATYPES:
# <img src="MySQL-Data-Types-.jpg">

# %% [markdown]
# ##### Numeric Datatype :
# 1.  INTEGER/INT : 1. TINYINT 2. SMALLINT 3.MEDIUMINT 4.INTEGER 5. BIGINT
# 2.  DECIMAL(P,S): P=precision , S=Scale ; Default= DECIMAL(10,0)=1234567890,DECIMAL(9,2)=1234567.89
# 3.  STRING

# %% [markdown]
# #### OPERATORS
#
# 1. **Comparison Operator:**<br>
#     SELECT 1=0;      -- oputput=0(FALSE)<br>
#     SELECT 1!=0;     -- output=1(TRUE)<br>
#     SELECT 0.0=0;    --output=1(TRUE)<br>
#     SELECT "0"=0;    --output=1(TRUE)<br>
#     SELECT 0="0.0"   --output=1(TRUE)<br>
#     SELECT "0"="0.0" --output=0(FALSE)-Important <br>
#     SELECT  9>=7      --output=1(TRUE)<br>
#     SELECT  9>="7"      --output=1(TRUE)<br>
#     SELECT  "9">="7"    --output=1(TRUE)<br>
#
# 2. **Logical Operators:**<br>
#     SELECT NOT 1;   -- oputput=0(FALSE)<br>
#     SELECT 0 or 1;  -- oputput=1(TRUE)<br>
#     SELECT TRUE || FALSE;-- OR Operation oputput=1(TRUE)<br>
#     SELECT "String1" || "String2";  -- oputput=0(FALSE)<br>
#     SELECT 0 AND 0;  -- oputput=0(FALSE)<br>
#     SELECT TRUE && FALSE; -- And Operation oputput=0(FALSE)<br>
#     SELECT 0 XOR 1;  -- oputput=1(TRUE)<br>
#     SELECT NOT( 0 XOR 1);-- oputput=1(TRUE)<br>
#     SELECT 1 IS TRUE;    --output=1(TRUE)<br>
#     SELECT 0 IS TRUE;    --output=1(TRUE)<br>
#     SELECT NULL IS NULL; --output=1(TRUE)<br>
#     SELECT "NULL" IS NULL;-- oputput=0(FALSE)<br>
#     SELECT " " IS NULL;-- oputput=0(FALSE)<br>
#     SELECT 7 IN (1,5,9);  -- oputput=0(FALSE)<br>
#     SELECT 7 IN (1,7,9);  -- oputput=1(TRUE)<br>
#
# 3. **Arithmatic Operator:**<br>
#     SELECT 5+3;   -- oputput=8<br>
#     SELECT 5-3;   -- oputput=2<br>
#     SELECT 5\*3;   -- oputput=15<br>
#     SELECT 5/3;   -- oputput=1.6667<br>
#     SELECT DIV(5,3); -- Gives error<br>
#     SELECT 5 div 3;   -- oputput=1# Integer Result<br>
#     SELECT MOD(5,3); -- oputput=2# Prints Remainder<br>
#     SELECT 5 mod 3;   -- oputput=2# Prints Remainder<br>
#     SELECT 5 % 3;     -- oputput=2# Prints Remainder<br>
#     SELECT 5/0;   -- oputput=null<br>

# %% [markdown]
# ###### SERIAL
# INT UNSIGNED UNIQUE AUTO_INCREMENT PRIMARY KEY == SERIAL
#
# ie : ID INT UNSIGNED UNIQUE AUTO_INCREMENT PRIMARY KEY is same as ID SERIAL

# %% [markdown]
# ##### Maths
#
# 1. SELECT ABS(-4.569654); O/P=4.569654
# 2. SELECT FLOOR(-4.569654); O/P=-5
# 3. SELECT CEILING(-4.569654); O/P=-4
# 4. SELECT ROUND(4.4); O/P=4
# 5. SELECT ROUND(4.5); O/P=5
# 6. SELECT ROUND(4.45689,2); O/P=4.46
# 6. SELECT TRUNCATE(4.456,2); O/P=4.45
# 7. SELECT ROUND(4.456,0); O/P=4
# 7. SELECT TRUNCATE(4.456,0); O/P=4
# 8. SELECT POWER(2,3);        O/P=8
# 9. SELECT PI();              O/P=3.141593
# 10. SELECT SQRT(25);         O/P=5
# 11. SELECT SQRT(-25);        O/P=null
# 12. SELECT POW(4096,1/4);    O/P=8
# 13. SELECT RAND();           O/P=Any arbitary random number
# 14. SELECT SIN(30);          O/P=-0.9880316240928618(Default argument in Rads)
# 15. SELECT SIN(PI()/2);      O/P=1
# 16. SELECT ASIN(1);          O/P=1.5707963267948966
# 17. SELECT LN(2);            O/P=0.6931471805599453
# 18. SELECT LN(0);            O/P=null
# 19. SELECT LOG(10,100);      O/P=2
# 20. SELECT LOG2(2);          O/P=1
# 21. SELECT LOG110(10);       O/P=1
# 22. SELECT EXP(1);           O/P=2.718281828459045(Inverse Log:e\**1)
# 23. SELECT DEGREES(PI());    O/P=180
# 24. SELECT RADIANS(90);      O/P=1.5707963267948966
# 25. SELECT SIGN(4.44);       O/P= 1
# 26. SELECT SIGN(0.00);       O/P=0
# 27. SELECT SIGN(-4.44);      O/P=-1|

# %% [markdown]
# ##### Number System
#
# 1. SELECT 8; O/P=8
# 2. SELECT BIN(8);  O/P=1000
# 3. SELECT OCT(8); O/P=10
# 4. SELECT HEX(8); O/P=8
# 5. SELECT CONV(25, 10 , 2); O/P=11001,Converts 25 to its binary form

# %% [markdown]
# ##### Date

# %% [markdown]
# - SELECT DATE('2012-03-19 10:42:46');
# - SELECT YEAR('2012-03-19 10:42:46');
# - SELECT QUARTER('2012-03-19 10:42:46');
# - SELECT MONTH('2012-03-19 10:42:46');
# - SELECT MONTHNAME('2012-03-19 10:42:46');
# - SELECT DAY('2012-03-19 10:42:46');
# - SELECT DAYNAME('2012-03-19 10:42:46');
# - SELECT TIME('2012-03-19 10:42:46');
# - SELECT HOUR('2012-03-19 10:42:46');
# - SELECT MINUTE('2012-03-19 10:42:46');
# - SELECT SECOND('2012-03-19 10:42:46');
# - SELECT WEEKOFYEAR('2012-03-19 10:42:46');
# - SELECT YEARweek("2012-03-19 18:34:16");

# %% [markdown]
# ##### Datediff()

# %% [markdown]
# The first argument in datediff() need to have a larger value as the function produces result as 1st_argument-2nd_argument
#
# - SELECT datediff(now(),"1996-08-20");             -- Age in number of days
# - SELECT datediff(now(),"1996-08-20")/365;         -- Converting Days to Year Years
# -

# %% [markdown]
# ##### Pivot Table

# %% [markdown]
# **1. Pandas**<br>
# https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.pivot_table.html

# %%
import pandas as pd
import numpy as np 

df = pd.DataFrame({"A": ["foo", "foo", "foo", "foo", "foo",
                         "bar", "bar", "bar", "bar"],
                   "B": ["one", "one", "one", "two", "two",
                         "one", "one", "two", "two"],
                   "C": ["small", "large", "large", "small",
                         "small", "large", "small", "small",
                         "large"],
                   "D": [1, 2, 2, 3, 3, 4, 5, 6, 7],
                   "E": [2, 4, 5, 5, 6, 6, 8, 9, 9]})
df
# Out:
#      A    B      C  D  E
# 0  foo  one  small  1  2
# 1  foo  one  large  2  4
# 2  foo  one  large  2  5
# 3  foo  two  small  3  5
# 4  foo  two  small  3  6
# 5  bar  one  large  4  6
# 6  bar  one  small  5  8
# 7  bar  two  small  6  9
# 8  bar  two  large  7  9

# %%
table = pd.pivot_table(df, values=['D','E'], index=['A', 'B'],columns=['C'], aggfunc=np.sum)

# %%
table
# Out:
#             D           E
# C       large small large small
# A   B
# bar one   4.0   5.0   6.0   8.0
#     two   7.0   6.0   9.0   9.0
# foo one   4.0   1.0   9.0   2.0
#     two   NaN   6.0   NaN  11.0

# %% [markdown]
# **2. SQL**

# %% [markdown]
# **Q. There are 3 unique product IDs(1,2,3). Find out how many of each product IDs are ordered in terms of the item_purchased**

# %% [raw]
# Table : orders
# order_id         Created_at        session_id   user_id   product_id item_purchased       Price(USD)
# 1	        2012-03-19 10:42:46	      20	      20	      1	      1	                  49.99
# 2	        2012-03-19 19:27:37	      104	      104	      1	      1	                  49.99
# 3	        2012-03-20 06:44:45	      147	      147	      1	      1	                  49.99
# 4	        2012-03-20 09:41:45	      160	      160	      1	      1	                  49.99
# 5	        2012-03-20 11:28:15	      177	      177	      2	      2	                  49.99
# 6	        2012-03-20 16:12:47	      232	      232	      1	      1	                  49.99
# 7	        2012-03-20 17:03:41	      241	      241	      1	      1	                  49.99
# 8	        2012-03-20 23:35:27	      295	      295	      1	      1	                  49.99
# 9	        2012-03-21 02:35:01	      304	      304	      1	      2	                  49.99
# 10	        2012-03-21 06:45:58	      317	      317	      3	      1	                  49.99

# %% [raw]
# SELECT product_id,
# COUNT(DISTINCT CASE WHEN item_purchased=1 THEN order_id else NULL end ) as count_single_item_orders,
# COUNT(DISTINCT CASE WHEN item_purchased=2 THEN order_id else NULL end ) as count_double_item_orders
# FROM orders
# groupby product_id

# %% [raw]
# OUTPUT
# product_id    count_single_item_orders       count_double_item_orders
# 1	          18104	                            5757
# 2	          3924	                            879

# %% [markdown]
# ##### CASE
# In SQL --> Case = If Else Statement <br>
# Example 1 :
# 1. SELECT Product_Name,
#     (Case
#         When Profit>50000 then "Huge Profit"
#         When Profit<0 then "Loss"
#         when ((Profit>10000) or (Profit<50000)) then "Medium Profit"
#         else "Small Profit"
#      end) as Profit_Classes
#
#    From Products;
#
# Example 2 :<br>
# 2. use india;<br>
#         select State,round(avg(literacy),2) as literacy,<br>
#         (Case	 <br>
#         when literacy>=80 then "High"<br>
#         when literacy <80 then "Low"	<br>
#         end ) as literacy_state <br>
#      from literacy group by state ;

# %% [markdown]
# #### Set operators in SQL : Union , Union All , Munus and Intersection
#
# - **Union:** It combines two or more results from multiple SELECT queries into a single result set. <u>It has a default feature to remove the duplicate rows from the tables</u>
#
# - **Union All:** This operator is similar to the Union operator, but it does not remove the duplicate rows from the output of the SELECT statements
#
# - **Intersection :** This operator returns the common records from two or more SELECT statements. It always retrieves unique records and arranges them in ascending order by default. Here, the number of columns and data types should be the same
#
# - **Minus:** This operator returns the records from the first query, which is not found in the second query. It does not return duplicate values.<br>
#
# Used to Joining 2 tables up/down; It can sometimes be treated as alternative approach of CASE <br>
# ***Example***<br>
# use india;<br>
# select State,round(avg(literacy),2) as literacy,"High" as Literacy_status <br>
# from literacy group by state having literacy>=80<br>
# UNION<br>
# select State,round(avg(literacy),2) as literacy,"Low" as Literacy_status<br> from literacy group by state having literacy<80 order by literacy desc;

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ##### String
#
# 1. Concatenation:
#
#     - SELECT CONCAT("String1" ,"String2"); O/P=String1String2
#     - SELECT "String1"+"String2"; O/P=String1String2
#     - SELECT CONCAT_WS('.', 'www', 'W3Schools', 'com'); O/P=www.W3Schools.com/ CONCAT_WS=Concat with Seperator
# 2. TRIM
#
#     - SELECT TRIM("    Krishnendu    ");-- Removes the extra spaces from both sides
#     - SELECT LTRIM("    Krishnendu    ");--Removes the extra spaces from the left side only
#     - SELECT RTRIM("    Krishnendu    ");--Removes the extra spaces from the right side only
#     - SELECT TRIM("x" FROM "xxxxxxKrishnendu    ");-- Removes the "x"s from the string Krishnendu not the spaces
#
# 3. Case:
#     - SELECT UCASE("Krishnendu"); -- Prints all in Capital
#     - SELECT UPPER("Krishnendu"); -- Prints all in Capital
#     - SELECT LCASE("Krishnendu");-- Prints all in Small
#     - SELECT LOWER("Krishnendu");-- Prints all in Small

# %% [markdown]
# #### Some builtin String function in SQL
# ![image.png](attachment:image.png)
# ![image-2.png](attachment:image-2.png)<br>
# Link : https://www.youtube.com/watch?v=vN4sy5nHn6k&list=PL08903FB7ACA1C2FB&index=24&ab_channel=kudvenkat

# %% [markdown]
# **Left,Right,Locate,Repeat**<br>
#
# select left("krishnendu",4);  // output = "kris"<br>
# select right("krishnendu",4); // output = 'endu'<br>
# select locate('k','krishnendu'); //output= 1<br>
# select repeat("X",5);         // output = 'XXXXX'<br>
# select space(5); // output = 5 spaces<br>
# select replace('kd@gmail.com','.com','.net'); //output = kd@gmail.net<br>

# %% [markdown]
# ##### SUBSTRING
#
# - SELECT SUBSTRING("KRISHNENDU",6);--Prints"NENDU" ie everything starting from 6th index[Initial=1]
# - SELECT SUBSTRING("KRISHNENDU",6,3);--Prints "NEN" ;3 symbolises how many characters are needed to be returned
# - SELECT LEFT("KRISHNENDU",4)--print : "KRIS"
# - SELECT RIGHT("KRISHNENDU",4)--print : "ENDU"
# - SELECT SUBSTRING("KRISHNENDU",1,1)--print : K(Prints first letter only)
# - SELECT SUBSTRING("KRISHNENDU",length("KRISHNENDU"),1);--print : U(Prints last letter only)
# - SELECT REVERSE(substring('Sachin Tendulkar', -7, 3));--O/P : udn

# %% [markdown]
# substring index: https://www.geeksforgeeks.org/substring_index-function-in-mysql/

# %% [markdown]
# ##### Like

# %% [markdown]
# - The percent sign (%) represents zero, one, or multiple characters
# - The underscore sign (_) represents one, single character
#
# Syntax: SELECT column1, column2, ... FROM table_name  WHERE columnN LIKE pattern;<br>
# Example:<br>
# Q. Select those countries that has "a" as its 2nd character in the name <br>
# A. SELECT countryname FROM country where countryname like "_%a"

# %% [markdown]
# <u>LIKE Operator	Description: </u>
# - WHERE CustomerName LIKE 'a%'	Finds any values that start with "a"
# - WHERE CustomerName LIKE '%a'	Finds any values that end with "a"
# - WHERE CustomerName LIKE '%or%'	Finds any values that have "or" in any position
# - WHERE CustomerName LIKE '_r%'	Finds any values that have "r" in the second position
# - WHERE CustomerName LIKE 'a_%'	Finds any values that start with "a" and are at least 2 characters in length
# - WHERE CustomerName LIKE 'a__%'	Finds any values that start with "a" and are at least 3 characters in length
# - WHERE ContactName LIKE 'a%o'	Finds any values that start with "a" and ends with "o"

# %% [markdown]
# <u>Wildcard Characters in SQL Server</u><br>
# Symbol-Description <br>
# - %	Represents zero or more characters	bl% finds bl, black, blue, and blob
# - _	Represents a single character	h_t finds hot, hat, and hit
# - []	Represents any single character within the brackets	h[oa]t finds hot and hat, but not hit
# - ^	Represents any character not in the brackets	h[^oa]t finds hit, but not hot and hat
# - \-	Represents a range of characters	c[a-b]t finds cat and cbt

# %% [markdown]
# ###### STRCMP()
#
# Q. Select all the districts upto kolkata in an alphebetical order;<br>
# A. select district from literacy where strcmp(district,' Kolkata') <=0 order by district;

# %% [markdown]
# ###### RLIKE
#
# Q. Select those states that has h or r in its name followed by a or l:<br>
# A. select distinct state from literacy where state rlike '[hr][al]';

# %% [markdown]
# ##### Basics

# %% [markdown]
# 1. select "Hello world";  -- To print "Hello world"
# 2. SELECT 1+2;            -- Prints 3
# 3. SHOW databases;        -- To print all the databases
# 4. SHOW TABLES;           -- To print all the tables inside a database
# 5. DESC TableName;        -- To print the Column details of a Table
# 6. USE DBNAME;            -- To use a perticular database
# 7. SELECT NOW();          -- Prints the time of the moment
# 8. SET TIME_ZONE='SYSTEM';-- Sets the time as per the system time_zone
# 9. SELECT utc_timestamp();-- Prints the UTC time\
# 10. SELECT ASCII("A");-- Prints ASCII value of A= 65
# 11.

# %% [markdown]
# ##### CREATE TABLE

# %% [markdown]
# CRAETE TABLE TABLENAME (<br>
# COL1 INT AUTO INCREMENT PRIMARY KEY,<br>
# COL2 VARCHAR(20),<br>
# COL3 CHAR(10),<br>
# STAMP TIMESTAMP)

# %% [markdown]
# #### Creating a Table from the existing table
#
# use india;<br>
#
# <u>create table LiteracyByStates as</u><br>
# select State,round(avg(literacy),2) as Avg_literacy, count(District) AS Districts<br>
#  from literacy group by state order by Avg_literacy desc;<br>
#
# select * from LiteracyByStates;

# %% [markdown]
# ##### Select

# %% [markdown]
# - SELECT * FROM TABLENAME;                             -- Select the whole table
# - SELECT COLNAME FROM TABLENAME;                       -- Select only selective column from table
# - SELECT COLNAME as COL FROM TABLENAME;                -- Select only selective column from table using alias

# %% [markdown]
# ##### COUNT

# %% [markdown]
# - SELECT COUNT(*) FROM TABLENAME;                    - Counts the number of rows in the table
# - SELECT COUNT(COLNAME) FROM TABLENAME;              - Counts the number of records(rows) where the COLNAME has data

# %% [markdown]
# ##### INSERT INTO()

# %% [markdown]
# Inserting only one row into the Table :
#
# - INSERT INTO TABLENAME (COL1,COL2,COL3...) VALUES (VAL1,VAL2,VAL3.....)
# - INSERT INTO TABLENAME VALUES (VAL1,VAL2,VAL3.....)
#
# Inserting Multiple row into the table :
#
# - INSERT INTO TABLENAME VALUES(VAL1,VAL2,VAL3....),VALUES(VAL1,VAL2,VAL3.....).............. n rows

# %% [markdown]
# ##### UPDATE

# %% [markdown]
# - UPDATE TABLENAME SET COL1=VALUE1,COL2=VALUE2 ;
# - UPDATE TABLENAME SET COL1=VALUE1,COL2=VALUE2 WHERE CONDITION ;   -- Updating specific entries

# %% [markdown]
# ##### DELETE / DROP

# %% [markdown]
# - DELETE FROM TABLENAME;                  -- Deleting all the rows of the table TABLENAME but doesnot delete the table
# - DELETE FROM TABLENAME WHERE CONDITION;  -- Deleting perticular row(s) based on where condition
# - DROP TABLE TABLENAME;                   -- Deleting the entire table named TABLENAME
# - DROP DATABASE DATABASENAME;             -- Deleting the entire database

# %% [markdown]
# KEVIN SCHODLENDS - REGEXP Course

# %% [markdown]
# Practice Location <br>
# Link : https://www.w3resource.com/sql-exercises/
#
# importants :
# 1. SQL Retrieve data from tables [33 Exercises] - Problem 17

# %% [markdown]
# ##### Difference Between Where and Having:
# -  WHERE  clause is used for the base table of a database
# -  HAVING clause is used for the groupby-aggregate table of the database
# - WHERE clause can be used with SELECT, INSERT or UPDATE clause but HAVING can only be used with the SELECT clause.
# - WHERE Clause filters rows before aggregation and whereas HAVING clause filters groups after aggregations are performed

# %% [raw]
# Example:
# Use India;
# SELECT STATE,AVG(LITERACY) from Literacy group by State having State=" West Bengal"; --Using where post groupby gives error

# %% [markdown]
# **Commit and Rollback**

# %% [markdown]
# - If autocommit is set to 1 then whatever changes we are making to the tables are made permanent by default.To make things permanent we need to then use commit statement to make things permanenet.
# - To check if autocommit status, run command : **SELECT @@autocommit;**
# - By default @@autocommit is set to 1. Which means any kind of insert,update,delete operation to the tables are made permanent.
# - To set autocommit to 0, run the command : **SET autocommit=0; / SET autocommit= OFF;**
# - To make permanent chnages to the database use command : **COMMIT;**
# - Setting autocommit=0 gives us the option to **rollback** ie undo any changes made in the database before making final commit.After commit statement is done then rollback is not possible
# - using the command : **ROLLBACK;**, we are able to undo the last temporary changes made into the table

# %% [raw]
# Example :
# - To delete the employee with employee_id=4 :
#
# use dbname;
# select @@autocommit;
# set autocommit=0;
# Delete from employee where employee_id=4;
#
# - To rollback the changes :
#
# use dbname;
# select @@autocommit;
# set autocommit=0;
# Delete from employee where employee_id=4;
# ROLLBACK;
#
# - To make final commit :
#
# use dbname;
# select @@autocommit;
# set autocommit=0;
# Delete from employee where employee_id=4;
# COMMIT;

# %% [markdown]
# **Truncate Vs Delete**

# %% [markdown]
# Both Truncate and Delete statements can be used to delete records from the table without deleting the column names and its constraints.
# <br>
# Differences : <br>
# 1. Truncarte is a DDL and can not be rolled back if autocommit=0
# 2. DELETE is a DML and can be rolled back
# 3. Truncate Syntax : ***Truncate table Table_name;***
# 4. Delete Syntax : ***Delete from Table_name where primary_key between 1 and n;***

# %% [markdown]
# #### JOINS

# %% [markdown]
# <img src="Joins.png">

# %% [markdown]
# **1. INNER JOIN:** Joining Multiple Tables within the Same Database <br>
# In SQL, JOIN means INNER Join by Default

# %% [markdown]
# ***Explicit Join Sytax***

# %% [raw]
# Example:
#
# USE CustomerOrder;
# SELECT C.Customer_id, O.Order_id, C.CustomerName, O.Product
# FROM Customer C
# JOIN Order O
# ON C.Customer_id=O.Customer_id

# %% [markdown]
# ***Implicit Join Sytax***

# %% [raw]
# Example:
#
# USE CustomerOrder;
# SELECT C.Customer_id, O.Order_id, C.CustomerName, O.Product
# FROM  Customer C, Order O
# WHERE C.Customer_id=O.Customer_id

# %% [markdown]
# **Joining Across Multiple Databases:**<br>
# Those Column name or Tables are to be prefixed which are not part of the current database in use.

# %% [raw]
# Example:
# (Here we try to join Customer table in CustomerOrder Database to the Inventory table in ManufacturerData Database)
#
# USE CustomerOrder;
# SELECT C.Customer_id, C.CustomerName, I.Product_Manufacturer
# FROM Customer C
# JOIN ManufacturerData.Inventory I
# ON C.Product_id=I.Product_id

# %% [markdown]
# **2. SELF INNER JOIN**<br>
# Joining a Table within itself and not with any other Table.Only one Table is used

# %% [raw]
# Table:Employees
# emp_id | emp_name | job_name  | manager_id | hire_date  | salary  | commission | dep_id
# --------+----------+-----------+------------+------------+---------+------------+--------
#   68319 | KAYLING  | PRESIDENT |            | 1991-11-18 | 6000.00 |            |   1001
#   66928 | BLAZE    | MANAGER   |      68319 | 1991-05-01 | 2750.00 |            |   3001
#   67832 | CLARE    | MANAGER   |      68319 | 1991-06-09 | 2550.00 |            |   1001
#   65646 | JONAS    | MANAGER   |      68319 | 1991-04-02 | 2957.00 |            |   2001
#   67858 | SCARLET  | ANALYST   |      65646 | 1997-04-19 | 3100.00 |            |   2001
#   69062 | FRANK    | ANALYST   |      65646 | 1991-12-03 | 3100.00 |            |   2001
#   63679 | SANDRINE | CLERK     |      69062 | 1990-12-18 |  900.00 |            |   2001
#   64989 | ADELYN   | SALESMAN  |      66928 | 1991-02-20 | 1700.00 |     400.00 |   3001
#   65271 | WADE     | SALESMAN  |      66928 | 1991-02-22 | 1350.00 |     600.00 |   3001

# %% [raw]
# Q. Find all the employees and their respective managers
#
# USE HRDataset;
#
# SELECT E.emp_id,M.manager_id,E.emp_name
# FROM Employees E
# JOIN Employees M
# ON E.manager_id=M.emp_id
#
#
# ##Extracts all the employees who have a manager.Employee KAYLING has no manager so he is the CEO. For this Join the row containing emp_name='KAYLING' will not be extracted.

# %% [markdown]
# **Joining Multiple Tables**

# %% [raw]
# Example:
#
# USE CustomerOrder;
#
# SELECT C.Customer_id,O.Product_id,P.ProductName
# FROM Customers C
# JOIN Orders O
#     ON C.Customer_id=O.Customer_id
# Join Products P
#     ON O.Product_id=P.product_id

# %% [markdown]
# **3. OUTER JOIN**

# %% [markdown]
# ***3.1 LEFT JOIN***<br>
# For left join all the keys for the left table will be displayed and it doesn't care whether right table has not null values for that left key or not

# %% [raw]
# Example:
#
# SELECT C.Customer_id,O.Order_id,O.City
# FROM Customers C                                 -- Customers Table : Left Table (All the Not null values are extracted)
# LEFT JOIN Orders O                               -- Orders Table: Left Table     (Null+Not Null Values are extracted)
#     ON C.Customer_id=O.Customer_id
# ORDER BY Customer_id
#
#
#
# OUTPUT:
# Customer_id  |   Order_id     |    city
# -------------+----------------+------------+
#         3001 |  100           | New York   |
#         3003 |  103           | New York   |
#         3004 |  null          | California |
#         3005 |  104           | London     |
#         3006 |  101           | Paris      |
#         3007 |  null          | Berlin     |
#         3009 |  102           | Moscow     |
#         3010 |  null          | London     |

# %% [markdown]
# ***3.2 RIGHT JOIN***<br>
# For right join all the keys for the right table will be displayed and it doesn't care whether left table has not null values for that right key or not

# %% [raw]
# Example:
#
# SELECT C.Customer_id,O.Order_id,O.City
# FROM Orders O                                     -- Orders Table: Left Table      (Null+Not Null Values are extracted)
# RIGHT JOIN Customers C                            -- Customers Table : Right Table (All the Not null values are extracted)
#     ON C.Customer_id=O.Customer_id
# ORDER BY Customers C
#
#
#
# OUTPUT:
# Customer_id  |   Order_id     |    city
# -------------+----------------+------------+
#         3001 |  100           | New York   |
#         3003 |  103           | New York   |
#         3004 |  null          | California |
#         3005 |  104           | London     |
#         3006 |  101           | Paris      |
#         3007 |  null          | Berlin     |
#         3009 |  102           | Moscow     |
#         3010 |  null          | London     |

# %% [markdown]
# **4. Self OUTER join**

# %% [raw]
# Table:Employees
# emp_id | emp_name | job_name  | manager_id | hire_date  | salary  | commission | dep_id
# --------+----------+-----------+------------+------------+---------+------------+--------
#   68319 | KAYLING  | PRESIDENT |            | 1991-11-18 | 6000.00 |            |   1001
#   66928 | BLAZE    | MANAGER   |      68319 | 1991-05-01 | 2750.00 |            |   3001
#   67832 | CLARE    | MANAGER   |      68319 | 1991-06-09 | 2550.00 |            |   1001
#   65646 | JONAS    | MANAGER   |      68319 | 1991-04-02 | 2957.00 |            |   2001
#   67858 | SCARLET  | ANALYST   |      65646 | 1997-04-19 | 3100.00 |            |   2001
#   69062 | FRANK    | ANALYST   |      65646 | 1991-12-03 | 3100.00 |            |   2001
#   63679 | SANDRINE | CLERK     |      69062 | 1990-12-18 |  900.00 |            |   2001
#   64989 | ADELYN   | SALESMAN  |      66928 | 1991-02-20 | 1700.00 |     400.00 |   3001
#   65271 | WADE     | SALESMAN  |      66928 | 1991-02-22 | 1350.00 |     600.00 |   3001

# %% [raw]
# Q. Find all the employees and their respective managers
#
# USE HRDataset;
#
# SELECT E.emp_id,M.manager_id,E.emp_name
# FROM  Employees E
# LEFT  JOIN Employees M
#     ON E.manager_id=M.emp_id
#
# ## Extracts all the employees who have a manager.Employee KAYLING has no manager so he is the CEO. For this Left Join the row containing emp_name='KAYLING' will also get printed as it doesn't bother about null value in manager_id column

# %% [markdown]
# #### Joining using ON and Using:
# If the key on which the two tables are to be joined have same name then USING clause can be used else not<br>
# USING can be used for both Inner and Outer joins.
# - Using: Select C.CustomerName, O.ProductName from Customers C JOIN Orders O USING(order_id)
# - ON : Select C.CustomerName, O.ProductName from Customers C JOIN Orders O ON C.order_id=O.order_id

# %% [markdown]
# **Cross Join**<br>
# <u>A cross join is used when you wish to create a combination of every row from two tables.</u> All row combinations are included in the result; this is commonly called cross product join. A common use for a cross join is to create obtain all combinations of items, such as colors and sizes.if we join two tables having 15 and 20 columns the Cartesian product of two tables will be 15×20=300 rows.<br>
# Link : https://www.geeksforgeeks.org/difference-between-natural-join-and-cross-join-in-sql/<br>
# ![image-2.png](attachment:image-2.png)<br>

# %% [markdown]
# #### Which is more efficient between Joins and Nested Query ?
#
# - Executing a statement with the join clause creates a join index, which is an internal indexing structure. This makes it more efficient than a nested query. However, the nested query would perform better if you want to query data from a distributed database.
#
# - A distributed database has tables stored in different locations, instead of a local system. In this case, a nested query would perform better as we can extract the relevant information from different tables located on different computers. Then, we can merge the values to obtain the result. For a join, we would need to create a large table from the existing tables. Filtering from this large table would require comparatively more time.

# %% [markdown]
# #### Questions
#
# 1. Every SQL statement containing a 'join' keyword can be rewritten with a 'using' keyword. True/False ?
# 2. It's preferable to use 'union all' instead of 'union' in a query. True/False ?
# 3. Indexes require disk space for storage.True or False ?
# 4. What does the index for an employee table contain?
# 5. A Primary Key constraint always enforces both the UNIQUE and NOT NULL constraints.True/False ?
# 6. Fact or Dimension? What type of variable is the Order_ID in the shipping_dimen table shipping_dimen?
#     - Ship_id VARCHAR(12)
#     - Order_ID INT(11)
#     - Ship_Mode VARCHAR(25)
#     - Ship_Date DATE

# %% [markdown]
# #### Answers:
#
# 1. False : The 'using' keyword can be used in a query to join two tables only when the common column in the two tables has the same name in both tables.
# 2. False : Using union eliminates duplicate values in the result set, making it easier to look at and analyse the resulting output. Union all returns all values including duplicates.
# 3. True : Although you cannot see indexes whenever you execute queries, they take up storage space. Indexes are internal to the database engine
# 4. Employee ID and Location on the disk space for the perticular record.
# 5. True
# 6. The Order_ID is a dimension variable as it describes data qualitatively. A shipment having a particular order id associates it with an order made by a customer.

# %%
SELECT c.user_account_id,uc.first_name,uc.last_name,c.customer_id 
from contact c
join customer ct 
on
c.customer_id=ct.id
join user_account uc 
on c.user_account_id=uc.id

# %% [raw]
# SELECT c.user_account_id,uc.first_name,uc.last_name,c.customer_id ,ct.customer_name,2
# from contact c
# join customer ct
# on
# c.customer_id=ct.id
# join user_account uc
# on c.user_account_id=uc.id
# where c.customer_id=7

# %% [markdown]
# **Window Function**<br>
# - Source : Open MySQL workbench and from there open the **windowfunction** table
# - Link : https://www.mysqltutorial.org/mysql-window-functions/
#
# **Gereral Syntax:**<br>
# window_function_name(expression) OVER ( <br>
#    [partition_defintion]<br>
#    [order_definition]<br>
#    [frame_definition]<br>
# )

# %% [markdown]
# **Use of Partition**<br>
# - SELECT fiscal_year, SUM(sale)FROM sales GROUP BY fiscal_year;
# ![image.png](attachment:image.png)<br>
# - SELECT fiscal_year, sales_employee,sale,SUM(sale) OVER (PARTITION BY fiscal_year) total_sales FROM sales;
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# ### Advanced SQL

# %% [markdown]
# **1.Rank:**<br>
# Using the 'group by' clause, it leads to a reduction in the number of rows. It also leads to a loss of individual properties of various rows.
# To address the two points above, SQL provides for a special clause called the **over** clause, which provides the group characteristics to be displayed in the form of a new column. This leads to the preservation of the individual characteristics of different rows while displaying the group characteristics simultaneously.
#    - To get the ranks when the data are sorted to a perticular order.
#    - Syntax : **RANK() OVER(ORDER BY COLUMN_NAME)**
#
# Note : Refer to the literacybystates table in MySQL workbench<br>
#
# Example :
#    1. To get the Rank for all the states in terms of number of district it has :<br>
#         **select State,Districts, rank() over (order by Districts desc) as Ranks from literacybystates ;**
#    2. To get the state that has 5th Highest numbner of districts:<br>
#        **With Rank_Info as <br>
#         (select State,Districts, rank() over (order by Districts desc) as Ranks from literacybystates)<br>
#         select * from Rank_Info where Ranks<=5;**
#
#
# **1.1: Rank vs. Dense Rank :**<br>
#         ![image.png](attachment:image.png)
#
#
#
#
# ***Exercise***<br>
# Find the values of A and B?
# ![image-2.png](attachment:image-2.png)
# **Ans:** (A=5,B=9) Dense ranks are tightly packed, they have to be consecutive. The values of ranks depend on the number of similarly valued entries in a table, and they need not be consecutive. Since there are four entries with a rank 5, the next different entry would have a rank of 5 + 4 = 9.

# %% [markdown]
# **2. Partitioning**<br>
# In the previous segment, you learnt how to use the rank() and dense_rank() functions with the 'over' clause. However, that may not be enough if you want to rank groups of rows on some basis. For example, you can rank the top 10 batsmen in the world using rank(). But what if you want to find out the top three batsmen from each team? Here is where you would want to use the 'partition' and 'over' clauses together.<br>
#    - Syntax : **RANK()/DENSE_RANK() OVER (PARTITION BY column_to_partition ORDER BY ordering_criterion)**<br>
#
# Note : Table Literacy from database india is used <br>
#
# ***Example 1 ***:<br>
#   - Write a query to get the ranks of the literacy rates of all the districts within a state:<br>
#       **select State,district,Literacy, rank() over (partition by State order by Literacy) as Ranks from Literacy order by State;**
#
#
# ***Example 2 ***:<br>
#    - Write a query to get the Districts within each state with the literacy rate:<br>
#        **With Literacy_Rank as <br>
#       (select State,district,Literacy, rank() over (partition by State order by Literacy)
#       as Ranks from Literacy order by State )<br>
#         select * from Literacy_Rank where Ranks=1;**

# %% [markdown]
# **Index**<br>
# The best way to improve the
# performance of SELECT
# operations is to create indexes
# on one or more of the columns
# that are tested in the query. The
# index entries act like pointers to
# the table rows, allowing the
# query to quickly determine
# which rows match a condition in
# the WHERE clause, and retrieve
# the other column values for
# those rows. All MySQL data
# types can be indexed.

# %% [markdown]
# **Stored Procedure**<br>MySQL gives us the ability to
# store and call frequently used
# queries on the server. These are
# then referred to as ‘Procedures’,
# or commonly ‘Stored Procedures’<br>
# Benefits :  include more efficient
# query writing and query
# performance, and ability to share
# complex procedures more easily
# between Analysts and other
# database users

# %% [markdown]
# **Triggers**<br>
# MySQL allows us to create Triggers, where we can prescribe certain actions on a table to trigger one or more other actions to occur
# - We may prescribe that our triggered action occurs either BEFORE or AFTER an INSERT, UPDATE, or a DELETE
# - Triggers are a very common way to make sure related tables remain in sync as they are updated over time

# %% [markdown]
# **Views**<br>
# A view is like a “virtual table”; contents are defined by a query, and data is not physically created
# - One advantage of views is the ability to aggregate data from multiple tables into one view.
# - Another advantage is security – you can grant someone access to certain views, exclusively
# - Finally, altering views will not affect any downstream systems

# %% [markdown]
# #### Different ways to replace Null values in SQL-server

# %% [markdown]
# 1. **ISNULL():**<br>
#     Select firstName,ISNULL(middleName,"N/A") as middleName,lastName from Employees;
# 2. **COALESCE:**<br>
#     Select firstName,COALESCE(middleName,"N/A")as middleName,lastName from Employees;
# 3. **Case**<br>
#     SELECT firstName,<br>
#     case <br>
#         WHEN middleName is Null THEN "N/A" else middleName<br>
#     END <br>
#     as middleName,<br>
#     lastName <br>
#     from Employees;<br>

# %% [markdown]
# **coalesce() practical scenario:**<br>
#  Say, we want to take the firstname of the employee is it's not null, else we would take middle name if firstname is null otherwise we will take the last name if both the first and last names are null values.<br>
#
#  ![image.png](attachment:image.png)
